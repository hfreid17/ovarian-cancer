# %%
import pandas as pd
import numpy as np
import scipy as sc

# %%
# reading in TCGA ovarian cancer clinical data
df_clinical = pd.read_csv("/Users/maayanlab/Downloads/clinical.cart.2018-06-28/clinical.csv").set_index('submitter_id')

# %%
df_clinical.head()
# Out:
#                                            case_id project_id  gender  \
# submitter_id
# TCGA-29-2434  cb090048-9af1-489d-9ebe-7efaa3dc4e85    TCGA-OV  female
# TCGA-61-1738  72c40fba-f502-489b-ad87-843f52655894    TCGA-OV  female
# TCGA-61-1917  87cdf9a8-0579-4d3e-b4df-0f8eef63d7f4    TCGA-OV  female
# TCGA-13-2059  f4b56568-a74a-4a2e-89d9-11722ecf5948    TCGA-OV  female
# TCGA-13-0916  5f60bc2d-738f-43fc-a3fb-61ec6e80e3d4    TCGA-OV  female
#
#              year_of_birth                       race               ethnicity  \
# submitter_id
# TCGA-29-2434          1957                      white      hispanic or latino
# TCGA-61-1738          1945  black or african american            not reported
# TCGA-61-1917          1942                      white  not hispanic or latino
# TCGA-13-2059          1959                      white  not hispanic or latino
# TCGA-13-0916          1957                      white  not hispanic or latino
#
#              year_of_death classification_of_tumor last_known_disease_status  \
# submitter_id
# TCGA-29-2434            --            not reported              not reported
# TCGA-61-1738          2007            not reported              not reported
# TCGA-61-1917          2005            not reported              not reported
# TCGA-13-2059            --            not reported              not reported
# TCGA-13-0916            --            not reported              not reported
#
#              primary_diagnosis         ...            tumor_grade  \
# submitter_id                           ...
# TCGA-29-2434             C56.9         ...           not reported
# TCGA-61-1738             C56.9         ...           not reported
# TCGA-61-1917             C56.9         ...           not reported
# TCGA-13-2059             C56.9         ...           not reported
# TCGA-13-0916             C56.9         ...           not reported
#
#              tissue_or_organ_of_origin days_to_birth  \
# submitter_id
# TCGA-29-2434                     C56.9        -18997
# TCGA-61-1738                     C56.9        -21965
# TCGA-61-1917                     C56.9        -21972
# TCGA-13-2059                     C56.9        -18449
# TCGA-13-0916                     C56.9        -18189
#
#              progression_or_recurrence prior_malignancy  \
# submitter_id
# TCGA-29-2434              not reported     not reported
# TCGA-61-1738              not reported     not reported
# TCGA-61-1917              not reported     not reported
# TCGA-13-2059              not reported     not reported
# TCGA-13-0916              not reported     not reported
#
#              site_of_resection_or_biopsy days_to_last_follow_up  \
# submitter_id
# TCGA-29-2434                       C56.9                    349
# TCGA-61-1738                       C56.9                   1089
# TCGA-61-1917                       C56.9                   1321
# TCGA-13-2059                       C56.9                   2387
# TCGA-13-0916                       C56.9                   1785
#
#              therapeutic_agents treatment_intent_type treatment_or_therapy
# submitter_id
# TCGA-29-2434                 --                    --                   --
# TCGA-61-1738                 --                    --                   --
# TCGA-61-1917                 --                    --                   --
# TCGA-13-2059                 --                    --                   --
# TCGA-13-0916                 --                    --                   --
#
# [5 rows x 27 columns]

# %%
# reading in TCGA ovarian cancer expression file, normalized version

df_expression = pd.read_table("/Users/maayanlab/Documents/Ovarian Cancer Project/TCGA-OV-fpkm-uq.txt").set_index('gene_symbol')


# making list of patient (submitter) ids to use for the clinical analysis

sub_ids_exp = list(df_expression.columns.values)

# %%
## extracting rows from the clinical df for patients that are also in the expression df

# df_clinical_matches = df_clinical.index.str.match(list_submitter_ids_expression)

# for row in df_clinical.rows:
    
#     if row.index = 

# df_clinical_matches = df_clinical.loc[df.index.isin(list_submitter_ids_expression)]



sub_ids_clinical = list(df_clinical.index.values)
expressionLength = len(sub_ids_exp)
clinicalLength = len(sub_ids_clinical)
sub_ids_matches = []

x = 0 # variable to run through submitter ids clinical
y = 0 # variable to run through submitter ids expression

sub_ids_clinical_sorted=[]
sub_ids_exp_sorted=[]
sub_ids_clinical_sorted = df_clinical.index.sort_values(ascending=True)
sub_ids_exp_sorted = df_expression.columns.sort_values(ascending=True)


# while x < clinicalLength:
#     while y < expressionLength:
#         expression_id = submitter_id_expression_sorted[y]
#         if submitter_id_clinical_sorted[x] == (expression_id[0:12]):
#             list_submitter_ids_matches.append(submitter_id_clinical_sorted[x])
#         y = y + 1        
#     x = x + 1


  
# finding common submitter ids between clinical and expression data

expression_sliced = []
while y < expressionLength:
    exp_id = sub_ids_exp[y]
    expression_sliced.append(exp_id[0:12])
    y = y + 1
    

common_sub_ids = list(set(expression_sliced).intersection(set(sub_ids_clinical)))

# %%
# remaking dataframe from other jupyter notebook of top 500 and bottom 500 genes for each patient


import scipy.stats as ss


df_zscore2 = df_expression.T.apply(ss.zscore, axis=0).T.dropna().apply(ss.zscore, axis=0)


# define empty dictionary
results = {}


# Loop through samples
for sample in df_zscore2.columns[:]:
    
    # Extract column
    col = df_zscore2[sample].sort_values(ascending=False) # sort values in decreasing order
    
    genesets={
        "top":col.index[:500].tolist(),
        "bottom":col.index[-500:].tolist()


    }
    # Extract the top 500 genes from the index
    results[sample] = genesets
# Out:
# /Users/maayanlab/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:2253: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd

# %%
# making dataframe of top and bottom 500 genes for each patient and editing the df so that it can be merged with the clinical df

df_genes = pd.DataFrame(results)
df_genes = df_genes.T # transform
df_genes['submitter_id'] = expression_sliced # adding new column of what will be the index
df_genes.set_index('submitter_id', inplace=True) # replacing index with version that does not have extra numbers at end

# %%
# combining the clinical and expression dataframes for common submitter ids

df_combined = pd.DataFrame()
df_combined = pd.merge(df_clinical, df_genes, how='inner', on=["submitter_id"])

# %%
df_combined.head()
# Out:
#                                            case_id project_id  gender  \
# submitter_id
# TCGA-61-1738  72c40fba-f502-489b-ad87-843f52655894    TCGA-OV  female
# TCGA-13-0916  5f60bc2d-738f-43fc-a3fb-61ec6e80e3d4    TCGA-OV  female
# TCGA-61-1914  8e1b8811-1eb2-4337-852c-c19eaa0ee418    TCGA-OV  female
# TCGA-09-1659  644a88a7-dc56-468a-af5c-60278aab7642    TCGA-OV  female
# TCGA-13-1404  8e107f4b-1912-4d3e-814a-b863e2d65ed7    TCGA-OV  female
#
#              year_of_birth                       race               ethnicity  \
# submitter_id
# TCGA-61-1738          1945  black or african american            not reported
# TCGA-13-0916          1957                      white  not hispanic or latino
# TCGA-61-1914          1938               not reported            not reported
# TCGA-09-1659          1946                      white  not hispanic or latino
# TCGA-13-1404          1960                      white  not hispanic or latino
#
#              year_of_death classification_of_tumor last_known_disease_status  \
# submitter_id
# TCGA-61-1738          2007            not reported              not reported
# TCGA-13-0916            --            not reported              not reported
# TCGA-61-1914            --            not reported              not reported
# TCGA-09-1659          1997            not reported              not reported
# TCGA-13-1404            --            not reported              not reported
#
#              primary_diagnosis  \
# submitter_id
# TCGA-61-1738             C56.9
# TCGA-13-0916             C56.9
# TCGA-61-1914             C56.9
# TCGA-09-1659             C56.9
# TCGA-13-1404             C56.9
#
#                                     ...                         days_to_birth  \
# submitter_id                        ...
# TCGA-61-1738                        ...                                -21965
# TCGA-13-0916                        ...                                -18189
# TCGA-61-1914                        ...                                -23850
# TCGA-09-1659                        ...                                -18733
# TCGA-13-1404                        ...                                -17784
#
#              progression_or_recurrence prior_malignancy  \
# submitter_id
# TCGA-61-1738              not reported     not reported
# TCGA-13-0916              not reported     not reported
# TCGA-61-1914              not reported     not reported
# TCGA-09-1659              not reported     not reported
# TCGA-13-1404              not reported     not reported
#
#              site_of_resection_or_biopsy days_to_last_follow_up  \
# submitter_id
# TCGA-61-1738                       C56.9                   1089
# TCGA-13-0916                       C56.9                   1785
# TCGA-61-1914                       C56.9                   1722
# TCGA-09-1659                       C56.9                     --
# TCGA-13-1404                       C56.9                   2469
#
#              therapeutic_agents treatment_intent_type treatment_or_therapy  \
# submitter_id
# TCGA-61-1738                 --                    --                   --
# TCGA-13-0916                 --                    --                   --
# TCGA-61-1914                 --                    --                   --
# TCGA-09-1659                 --                    --                   --
# TCGA-13-1404                 --                    --                   --
#
#                                                          bottom  \
# submitter_id
# TCGA-61-1738  [KIF7, TASP1, SPDYE1, KDM2B, SOWAHC, PABPC1P4,...
# TCGA-13-0916  [HNRNPH1, UBL3, DIS3, SKI, BRMS1L, DNAJC3, SNR...
# TCGA-61-1914  [EP400, FAM193A, SECISBP2L, TMPPE, EIF4A1, WHS...
# TCGA-09-1659  [SP1, CEP131, XPNPEP3, PHF2, CTDSPL, TCAIM, RN...
# TCGA-13-1404  [ARHGEF34P, NAPA, SRSF9P1, TPCN1, KLHL21, GCC2...
#
#                                                             top
# submitter_id
# TCGA-61-1738  [RNA5SP63, SLC10A1, SLC16A14P1, UNGP1, MKX-AS1...
# TCGA-13-0916  [PNLIPRP3, GPN3P1, LINC00836, GPR50-AS1, RPL21...
# TCGA-61-1914  [RNU6-1037P, FAM159B, PRR21, HIST1H2APS6, IGLV...
# TCGA-09-1659  [CTAG2, RPL36P2, PNPLA4P1, RNU6-832P, OR5M4P, ...
# TCGA-13-1404  [RNA5SP458, RNU6-815P, MIR1238, RNU6-278P, RNU...
#
# [5 rows x 29 columns]

# %%
df_combined.to_excel("/Users/maayanlab/Documents/Ovarian Cancer Project/clinicalandgenescombined.xlsx")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_combined = df_combined.replace('--', None)
df_combined['age_at_diagnosis'] = df_combined['age_at_diagnosis'].astype(int)
df_combined['days_to_death'] = df_combined['days_to_death'].astype(int)

# %%
# exploratory plot--age at diagnosis and days until death

# making plot
sns.stripplot(x="age_at_diagnosis", y="days_to_death", data=df_combined)

plt.show()

# %%
# exploratory plot--race and survival
fig, ax = plt.subplots(figsize=(20,10))
sns.boxplot(x="race", y="days_to_death", data=df_combined)
plt.show()

# %%
### 1-calculate variance for each gene and make into df
## making heatmap from TCGA expression data--before zscores

# first, calculating variance across rows for each gene--only using top 500-2000 genes in the heatmap

expression_variance = []
expression_variance = df_expression.var(axis=1)

df_expression_variance = pd.DataFrame(expression_variance)

# %%
df_expression.head()
# Out:
#              TCGA-04-1331-01  TCGA-04-1332-01  TCGA-04-1338-01  \
# gene_symbol
# A1BG            8.458800e+03     2.614685e+03      4434.309873
# A1BG-AS1        3.444052e+04     1.036832e+04     14965.013669
# A1CF            7.588568e+01     6.416151e+01       217.626175
# A2M             1.029971e+06     2.413902e+06    733121.989928
# A2M-AS1         1.795229e+04     4.244415e+04     15731.185502
#
#              TCGA-04-1341-01  TCGA-04-1343-01  TCGA-04-1347-01  \
# gene_symbol
# A1BG             2582.015414      6492.212267      2698.654721
# A1BG-AS1        12300.528089     31535.895904      9031.587979
# A1CF              153.873845       108.331989         0.000000
# A2M            264849.878668    878116.400668    279320.674058
# A2M-AS1         25447.676880     26419.117949     57813.287740
#
#              TCGA-04-1350-01  TCGA-04-1356-01  TCGA-04-1357-01  \
# gene_symbol
# A1BG             1754.362644      6303.314039     1.237301e+03
# A1BG-AS1         7548.847211     26300.635787     7.764144e+03
# A1CF                0.000000       199.204447     0.000000e+00
# A2M            101619.097074    397155.010913     1.673852e+06
# A2M-AS1         30335.525712     87270.086956     3.872367e+04
#
#              TCGA-04-1361-01    ...     TCGA-61-2102-01  TCGA-61-2104-01  \
# gene_symbol                     ...
# A1BG            3.245218e+03    ...        1.275045e+03     3.293213e+03
# A1BG-AS1        1.151405e+04    ...        7.315191e+03     1.924808e+04
# A1CF            0.000000e+00    ...        1.181999e+02     1.030351e+02
# A2M             1.036686e+06    ...        1.835249e+06     1.273695e+06
# A2M-AS1         5.119228e+04    ...        7.430798e+04     2.377318e+04
#
#              TCGA-61-2109-01  TCGA-61-2110-01  TCGA-61-2111-01  \
# gene_symbol
# A1BG            1.221885e+03      2855.373781     2.645223e+03
# A1BG-AS1        4.301713e+03     15594.261879     1.277994e+04
# A1CF            4.633847e+01       595.575724     0.000000e+00
# A2M             1.267422e+06    321966.376566     1.080766e+06
# A2M-AS1         3.288691e+04     10235.997958     5.368607e+04
#
#              TCGA-61-2113-01  TCGA-OY-A56Q-01  TCGA-VG-A8LO-01  \
# gene_symbol
# A1BG             3646.483276     1.724258e+03       871.546913
# A1BG-AS1        23535.679920     4.608966e+03      2500.119537
# A1CF               33.068950     3.269517e+01       242.383764
# A2M            912988.250238     1.757632e+06    323993.355516
# A2M-AS1          8692.366711     2.694256e+05     25617.528442
#
#              TCGA-WR-A838-01  variance
# gene_symbol
# A1BG              255.829425       NaN
# A1BG-AS1         5137.106153       NaN
# A1CF              640.332819       NaN
# A2M            706780.188151       NaN
# A2M-AS1         59533.716967       NaN
#
# [5 rows x 380 columns]

# %%
df_expression_variance = df_expression_variance.T

# %%
print(df_expression_variance.columns.values)
# Out:
# [0]

# %%
df_expression_variance.head()
# Out:
#                         0
# gene_symbol
# A1BG         3.133371e+06
# A1BG-AS1     1.117022e+08
# A1CF         1.434501e+06
# A2M          8.265989e+11
# A2M-AS1      9.804144e+08

# %%
# 2-sort the values in variance column
df_expression_variance_sorted2 = df_expression_variance[0].sort_values(ascending = False)

# %%
# 3-make the sorted values into df
df_expression_variance_sorted3 = pd.DataFrame(df_expression_variance_sorted2)

# %%
df_expression_variance_sorted3.head()
# Out:
#                         0
# gene_symbol
# MT-RNR2      2.309822e+16
# MT-CO2       2.213050e+16
# MT-TP        1.879754e+16
# MT-CO3       1.690706e+16
# MT-CO1       1.429985e+16

# %%
# 4-take the top 1000 values
df_expression_variance_sorted3_top1000 = df_expression_variance_sorted3[:1000]

# %%
# 5-merge to get expression for each patient of top 1000 genes with most variance
df_expression_variance_3_top1000 = pd.merge(df_expression_variance_sorted3_top1000, df_expression, how='inner', on=["gene_symbol"])

# %%
# 6-transform df
df_expression_variance_3_top1000 = df_expression_variance_3_top1000.T
# df_expression_variance_3_top1000 = df_expression_variance_3_top1000.drop(0)

# %%
df_expression_variance_3_top1000.drop("0", axis = 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-04647a350d65> in <module>()
# ----> 1 df_expression_variance_3_top1000.drop("0", axis = 0)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# -> 3108                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3109
#    3110         if inplace:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3138                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3139             else:
# -> 3140                 new_axis = axis.drop(labels, errors=errors)
#    3141             dropped = self.reindex(**{axis_name: new_axis})
#    3142             try:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4385             if errors != 'ignore':
#    4386                 raise KeyError(
# -> 4387                     'labels %s not contained in axis' % labels[mask])
#    4388             indexer = indexer[~mask]
#    4389         return self.delete(indexer)
#
# KeyError: "labels ['0'] not contained in axis"

# %%
df_expression_variance_3_top1000.head()
# Out:
# gene_symbol           MT-RNR2        MT-CO2         MT-TP        MT-CO3  \
# 0                2.309822e+16  2.213050e+16  1.879754e+16  1.690706e+16
# TCGA-04-1331-01  2.761593e+08  3.553849e+08  3.633470e+07  2.762905e+08
# TCGA-04-1332-01  4.713007e+08  1.712418e+08  3.491175e+07  1.400043e+08
# TCGA-04-1338-01  8.795808e+08  6.661549e+08  1.198752e+08  8.630326e+08
# TCGA-04-1341-01  2.212533e+08  3.768295e+08  9.948608e+07  2.820291e+08
#
# gene_symbol            MT-CO1        MT-ND4        MT-ND1       MT-RNR1  \
# 0                1.429985e+16  1.335116e+16  1.083349e+16  7.492360e+15
# TCGA-04-1331-01  2.629279e+08  3.496900e+08  1.973441e+08  1.207855e+08
# TCGA-04-1332-01  1.644195e+08  1.237862e+08  7.328492e+07  3.935351e+08
# TCGA-04-1338-01  8.596132e+08  7.695879e+08  4.811486e+08  1.862980e+08
# TCGA-04-1341-01  1.718720e+08  1.784073e+08  1.704816e+08  8.155190e+07
#
# gene_symbol            MT-ND3       MT-ATP6      ...              SUMO2  \
# 0                7.270470e+15  6.679419e+15      ...       6.161558e+11
# TCGA-04-1331-01  1.331302e+08  1.996453e+08      ...       2.434071e+06
# TCGA-04-1332-01  7.020468e+07  8.062515e+07      ...       8.390654e+05
# TCGA-04-1338-01  5.197812e+08  5.884502e+08      ...       2.123642e+06
# TCGA-04-1341-01  1.877791e+08  1.491603e+08      ...       2.595310e+06
#
# gene_symbol              PERP           TK1        UQCRC1      C1orf186  \
# 0                6.099037e+11  6.095039e+11  6.081758e+11  6.075712e+11
# TCGA-04-1331-01  7.580323e+05  9.161012e+05  2.195086e+06  1.940037e+06
# TCGA-04-1332-01  4.706528e+05  8.843191e+05  1.660882e+06  1.060625e+06
# TCGA-04-1338-01  2.118606e+06  9.775533e+05  1.594200e+06  1.223249e+06
# TCGA-04-1341-01  1.325149e+06  1.930434e+06  2.797422e+06  4.338028e+05
#
# gene_symbol              IL32           WT1      SLC2A4RG          MT1F  \
# 0                6.075153e+11  6.042389e+11  6.042027e+11  6.037839e+11
# TCGA-04-1331-01  1.344370e+05  1.155462e+06  2.934406e+06  5.049803e+05
# TCGA-04-1332-01  4.425707e+05  1.542979e+06  2.237499e+06  7.991266e+05
# TCGA-04-1338-01  1.509274e+06  1.751208e+06  1.499412e+06  8.917049e+05
# TCGA-04-1341-01  4.441240e+05  1.589381e+06  3.528187e+06  2.600947e+05
#
# gene_symbol              VWA1
# 0                6.035269e+11
# TCGA-04-1331-01  6.839129e+05
# TCGA-04-1332-01  1.892343e+06
# TCGA-04-1338-01  3.775372e+05
# TCGA-04-1341-01  1.169211e+06
#
# [5 rows x 1000 columns]

# %%
# 7-drop row of variance
df_expression_variance_3_top1000 = df_expression_variance_3_top1000[1:1001]

# %%
# 8-transform
df_expression_variance_3_top1000 = df_expression_variance_3_top1000.T

# %%
df_expression_variance_3_top1000.head()
# Out:
# gene_symbol           MT-RNR2        MT-CO2         MT-TP        MT-CO3  \
# TCGA-04-1331-01  2.761593e+08  3.553849e+08  3.633470e+07  2.762905e+08
# TCGA-04-1332-01  4.713007e+08  1.712418e+08  3.491175e+07  1.400043e+08
# TCGA-04-1338-01  8.795808e+08  6.661549e+08  1.198752e+08  8.630326e+08
# TCGA-04-1341-01  2.212533e+08  3.768295e+08  9.948608e+07  2.820291e+08
# TCGA-04-1343-01  5.336218e+08  4.106744e+08  1.561284e+08  3.566515e+08
#
# gene_symbol            MT-CO1        MT-ND4        MT-ND1       MT-RNR1  \
# TCGA-04-1331-01  2.629279e+08  3.496900e+08  1.973441e+08  1.207855e+08
# TCGA-04-1332-01  1.644195e+08  1.237862e+08  7.328492e+07  3.935351e+08
# TCGA-04-1338-01  8.596132e+08  7.695879e+08  4.811486e+08  1.862980e+08
# TCGA-04-1341-01  1.718720e+08  1.784073e+08  1.704816e+08  8.155190e+07
# TCGA-04-1343-01  3.001899e+08  1.838967e+08  1.121836e+08  1.569265e+08
#
# gene_symbol            MT-ND3       MT-ATP6      ...               PERP  \
# TCGA-04-1331-01  1.331302e+08  1.996453e+08      ...       7.580323e+05
# TCGA-04-1332-01  7.020468e+07  8.062515e+07      ...       4.706528e+05
# TCGA-04-1338-01  5.197812e+08  5.884502e+08      ...       2.118606e+06
# TCGA-04-1341-01  1.877791e+08  1.491603e+08      ...       1.325149e+06
# TCGA-04-1343-01  1.994743e+08  1.451559e+08      ...       8.316838e+05
#
# gene_symbol               TK1        UQCRC1      C1orf186          IL32  \
# TCGA-04-1331-01  9.161012e+05  2.195086e+06  1.940037e+06  1.344370e+05
# TCGA-04-1332-01  8.843191e+05  1.660882e+06  1.060625e+06  4.425707e+05
# TCGA-04-1338-01  9.775533e+05  1.594200e+06  1.223249e+06  1.509274e+06
# TCGA-04-1341-01  1.930434e+06  2.797422e+06  4.338028e+05  4.441240e+05
# TCGA-04-1343-01  8.709330e+05  2.782524e+06  2.122447e+06  1.324623e+06
#
# gene_symbol               WT1      SLC2A4RG          MT1F          VWA1  \
# TCGA-04-1331-01  1.155462e+06  2.934406e+06  5.049803e+05  6.839129e+05
# TCGA-04-1332-01  1.542979e+06  2.237499e+06  7.991266e+05  1.892343e+06
# TCGA-04-1338-01  1.751208e+06  1.499412e+06  8.917049e+05  3.775372e+05
# TCGA-04-1341-01  1.589381e+06  3.528187e+06  2.600947e+05  1.169211e+06
# TCGA-04-1343-01  1.677028e+06  3.874591e+06  1.000109e+06  1.456779e+06
#
# gene_symbol          IGKV2-29
# TCGA-04-1331-01  27425.329643
# TCGA-04-1332-01  14906.684157
# TCGA-04-1338-01  22471.657622
# TCGA-04-1341-01   1986.089430
# TCGA-04-1343-01   5593.075772
#
# [5 rows x 1001 columns]

# %%
df_expression_variance.column([""])

# %%
df_expression_variance = df_expression_variance.drop("gene_symbol", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-f711ebe0dd4a> in <module>()
# ----> 1 df_expression_variance = df_expression_variance.drop("gene_symbol", axis=0)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# -> 3108                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3109
#    3110         if inplace:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3138                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3139             else:
# -> 3140                 new_axis = axis.drop(labels, errors=errors)
#    3141             dropped = self.reindex(**{axis_name: new_axis})
#    3142             try:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4385             if errors != 'ignore':
#    4386                 raise KeyError(
# -> 4387                     'labels %s not contained in axis' % labels[mask])
#    4388             indexer = indexer[~mask]
#    4389         return self.delete(indexer)
#
# KeyError: "labels ['gene_symbol'] not contained in axis"

# %%
df_expression_variance = df_expression_variance.columns

# %%
df_expression_variance.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-5ed6082bd0f1> in <module>()
# ----> 1 df_expression_variance.head()
#
# AttributeError: 'RangeIndex' object has no attribute 'head'

# %%
df_expression['variance'] = df_expression.var(axis=0)

# %%
df_expression_variance.columns=["variance"]

# %%
df_expression.head()
# Out:
#              TCGA-04-1331-01  TCGA-04-1332-01  TCGA-04-1338-01  \
# gene_symbol
# A1BG            8.458800e+03     2.614685e+03      4434.309873
# A1BG-AS1        3.444052e+04     1.036832e+04     14965.013669
# A1CF            7.588568e+01     6.416151e+01       217.626175
# A2M             1.029971e+06     2.413902e+06    733121.989928
# A2M-AS1         1.795229e+04     4.244415e+04     15731.185502
#
#              TCGA-04-1341-01  TCGA-04-1343-01  TCGA-04-1347-01  \
# gene_symbol
# A1BG             2582.015414      6492.212267      2698.654721
# A1BG-AS1        12300.528089     31535.895904      9031.587979
# A1CF              153.873845       108.331989         0.000000
# A2M            264849.878668    878116.400668    279320.674058
# A2M-AS1         25447.676880     26419.117949     57813.287740
#
#              TCGA-04-1350-01  TCGA-04-1356-01  TCGA-04-1357-01  \
# gene_symbol
# A1BG             1754.362644      6303.314039     1.237301e+03
# A1BG-AS1         7548.847211     26300.635787     7.764144e+03
# A1CF                0.000000       199.204447     0.000000e+00
# A2M            101619.097074    397155.010913     1.673852e+06
# A2M-AS1         30335.525712     87270.086956     3.872367e+04
#
#              TCGA-04-1361-01    ...     TCGA-61-2102-01  TCGA-61-2104-01  \
# gene_symbol                     ...
# A1BG            3.245218e+03    ...        1.275045e+03     3.293213e+03
# A1BG-AS1        1.151405e+04    ...        7.315191e+03     1.924808e+04
# A1CF            0.000000e+00    ...        1.181999e+02     1.030351e+02
# A2M             1.036686e+06    ...        1.835249e+06     1.273695e+06
# A2M-AS1         5.119228e+04    ...        7.430798e+04     2.377318e+04
#
#              TCGA-61-2109-01  TCGA-61-2110-01  TCGA-61-2111-01  \
# gene_symbol
# A1BG            1.221885e+03      2855.373781     2.645223e+03
# A1BG-AS1        4.301713e+03     15594.261879     1.277994e+04
# A1CF            4.633847e+01       595.575724     0.000000e+00
# A2M             1.267422e+06    321966.376566     1.080766e+06
# A2M-AS1         3.288691e+04     10235.997958     5.368607e+04
#
#              TCGA-61-2113-01  TCGA-OY-A56Q-01  TCGA-VG-A8LO-01  \
# gene_symbol
# A1BG             3646.483276     1.724258e+03       871.546913
# A1BG-AS1        23535.679920     4.608966e+03      2500.119537
# A1CF               33.068950     3.269517e+01       242.383764
# A2M            912988.250238     1.757632e+06    323993.355516
# A2M-AS1          8692.366711     2.694256e+05     25617.528442
#
#              TCGA-WR-A838-01  variance
# gene_symbol
# A1BG              255.829425       NaN
# A1BG-AS1         5137.106153       NaN
# A1CF              640.332819       NaN
# A2M            706780.188151       NaN
# A2M-AS1         59533.716967       NaN
#
# [5 rows x 380 columns]

# %%
expression_variance_sorted = []
expression_variance_sorted.append(df_expression_variance["variance"].sort_values(ascending=False))
df_expression_variance_sorted = pd.DataFrame(expression_variance_sorted)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-96c226e5c997> in <module>()
#       1 expression_variance_sorted = []
# ----> 2 expression_variance_sorted.append(df_expression_variance["variance"].sort_values(ascending=False))
#       3 df_expression_variance_sorted = pd.DataFrame(expression_variance_sorted)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/range.py in __getitem__(self, key)
#     496
#     497         if is_scalar(key):
# --> 498             n = int(key)
#     499             if n != key:
#     500                 return super_getitem(key)
#
# ValueError: invalid literal for int() with base 10: 'variance'

# %%
df_expression_variance_sorted = df_expression_variance_sorted.T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-a0980e5c0364> in <module>()
# ----> 1 df_expression_variance_sorted = df_expression_variance_sorted.T
#
# NameError: name 'df_expression_variance_sorted' is not defined

# %%
df_expression_variance_sorted_top1000 = df_expression_variance_sorted[:1000] # df of the top 1000 genes with the most variance and their calculated variance

# %%
# making df of the expression for all patients of the top 1000 genes with the most variance
df_expression_top1000 = pd.merge(df_expression_variance_sorted_top1000, df_expression, how='inner', on=["gene_symbol"])

# %%
df_expression_top1000 = df_expression_top1000.drop("variance_x", axis=1)
df_expression_top1000 = df_expression_top1000.drop("variance_y", axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3b0310ed68fb> in <module>()
# ----> 1 df_expression_top1000 = df_expression_top1000.drop("variance_x", axis=1)
#       2 df_expression_top1000 = df_expression_top1000.drop("variance_y", axis=1)
#
# NameError: name 'df_expression_top1000' is not defined

# %%
import numpy

# %%
# making heatmap of the expression of the 1000 most variant genes

fig, ax = plt.subplots(figsize=(20,10))
sns.clustermap(np.log10(df_expression_top1000+1))


plt.show()

# %%
# making heatmap of the expression of the 1000 most variant genes

# fig, ax = plt.subplots(figsize=(20,10))
sns.clustermap(np.log10(df_expression_top1000+1), z_score=0, cmap="RdBu_r")


# plt.show()

# %%
# making heatmap of the expression of the 1000 most variant genes

# fig, ax = plt.subplots(figsize=(20,10))
sns.clustermap(np.log10(df_expression_variance_3_top1000+1), z_score=0, cmap="RdBu_r")


plt.show()

# %%
from matplotlib.mlab import PCA
PCA_plot = PCA(df_expression_variance_3_top1000)
